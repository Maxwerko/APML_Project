# %%
# %pip install numpy
# %pip install matplotlib
# %pip install scipy
# %pip install dipy
# Out:
# ...
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#    ------ --------------------------------- 2.1/12.8 MB 12.2 MB/s eta 0:00:01
#    -------------- ------------------------- 4.7/12.8 MB 12.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 7.6/12.8 MB 12.7 MB/s eta 0:00:01
#    -------------------------------- ------- 10.5/12.8 MB 13.0 MB/s eta 0:00:01
#    ---------------------------------------- 12.8/12.8 MB 12.8 MB/s  0:00:01
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------- ----------------------------- 2.1/8.1 MB 12.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.7/8.1 MB 11.7 MB/s eta 0:00:01
#    ------------------------------------ --- 7.3/8.1 MB 12.0 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 11.4 MB/s  0:00:00
# ...
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
